# %% [markdown]
# # **Wuzzauf Web Scraping Project**
# This project demonstrates my approach to web scraping job listings from Wuzzuf using Python. The goal is to extract valuable job-related data — such as titles, companies, locations, and more — in a structured format.<br>
#
# made by: <br>
# *Mostafa Mohamed Hussein* <br>
# *R1024#286*<br>

# %% [markdown]
# **Requisites** <br>
# - Follow the same steps as the "machine learning" jobs scraping<br>
# - Add (Company Location)<br>
# - Scrap all the pages of search results (not the first page only)<br>
# - Repeat for : "data analysis" , "data science" , "business intelligence"<br>
# - Collect all in ( one CSV File )<br>

# %% [markdown]
# **Steps**<br>
# - install new libraries ✔️ <br>
# - import all libraries ✔️ <br>
# - get all the required responses ✔️ <br>
# - extract all the contents "parsing" ✔️ <br>
# - fetch all needed informations ✔️ <br>
# - organize all the collected data ✔️ <br>
# - save the result in the proper format (in this case "CSV") ✔️ <br>

# %%
#!pip install requests
#!pip install bs4

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
class webscrap:

  def __init__(self):
    self.scraped_data = {
            'Title': [],
            'Link': [],
            'Occupation': [],
            'Company': [],
            'Specs': [],
            'Location': []
        }

  def fetch(self,url):
    self.url = url
    response = requests.get(self.url)
    response
    if response.status_code == 200:
      self.html = response.content
      self.soup = BeautifulSoup(self.html, 'lxml')
    else:
      print('Failed to fetch the page. please try again with another url')

  def get_titles(self,head,clas):
    self.head= head
    self.clas = clas
    titles = self.soup.find_all (self.head,{'class':self.clas})
    titles_lst = [title.text for title in titles]
    self.scraped_data['Title'] += titles_lst

  def get_links(self,head,clas):
    self.head= head
    self.clas = clas
    links = self.soup.find_all (self.head,{'class':self.clas})
    links_lst=[link.a['href'] for link in links]
    self.scraped_data['Link'] += links_lst

  def get_occupations(self,head,clas):
    self.head= head
    self.clas = clas
    occupations = self.soup.find_all(self.head,{'class':self.clas})
    occupations_lst = [occupation.text for occupation in occupations]
    self.scraped_data['Occupation'] += occupations_lst

  def get_companies(self,head,clas):
    self.head= head
    self.clas = clas
    companies = self.soup.find_all(self.head,{'class':self.clas})
    companies_lst = [company.text for company in companies]
    self.scraped_data['Company'] += companies_lst

  def get_specs(self,head,clas):
    self.head= head
    self.clas = clas
    specs = self.soup.find_all(self.head, {'class':self.clas})
    specs_lst = [spec.text for spec in specs]
    self.scraped_data['Specs'] += specs_lst

  def get_location(self,head,clas):
    self.head= head
    self.clas = clas
    locations = self.soup.find_all(self.head,{'class':self.clas})
    locations_lst = [location.text for location in locations]
    self.scraped_data['Location'] += locations_lst

# %%
ML = webscrap()
for i in range(3):
  ML.fetch(f'https://wuzzuf.net/search/jobs/?a=hpb&q=machine%20learning&start={i}')

  ML.get_titles('h2','css-m604qf')
  ML.get_links('h2','css-m604qf')
  ML.get_occupations('div','css-1lh32fc')
  ML.get_companies('a','css-17s97q8')
  ML.get_specs('div','css-y4udm8')
  ML.get_location('span','css-5wys0k')

ML_df = pd.DataFrame(ML.scraped_data)

# %%
DA = webscrap()
for i in range(53):
  DA.fetch(f'https://wuzzuf.net/search/jobs/?a=hpb%7Cspbg&q=data%20analysis&start={i}')

  DA.get_titles('h2','css-m604qf')
  DA.get_links('h2','css-m604qf')
  DA.get_occupations('div','css-1lh32fc')
  DA.get_companies('a','css-17s97q8')
  DA.get_specs('div','css-y4udm8')
  DA.get_location('span','css-5wys0k')

DA_df = pd.DataFrame(DA.scraped_data)

# %%
DS = webscrap()
for i in range(31):
  DS.fetch(f'https://wuzzuf.net/search/jobs/?a=hpb%7Cspbg&q=data%20science&start={i}')

  DS.get_titles('h2','css-m604qf')
  DS.get_links('h2','css-m604qf')
  DS.get_occupations('div','css-1lh32fc')
  DS.get_companies('a','css-17s97q8')
  DS.get_specs('div','css-y4udm8')
  DS.get_location('span','css-5wys0k')

DS_df = pd.DataFrame(DS.scraped_data)

# %%
BI = webscrap()
for i in range(8):
  BI.fetch(f'https://wuzzuf.net/search/jobs/?a=navbg&q=business%20intelligence&start={i}')

  BI.get_titles('h2','css-m604qf')
  BI.get_links('h2','css-m604qf')
  BI.get_occupations('div','css-1lh32fc')
  BI.get_companies('a','css-17s97q8')
  BI.get_specs('div','css-y4udm8')
  BI.get_location('span','css-5wys0k')

BI_df = pd.DataFrame(BI.scraped_data)

# %%
ML_df
# Out:
#                                                 Title  \
# 0                                      Data Scientist
# 1                                         AI Engineer
# 2                                      Data Scientist
# 3   Graduate Internship: Enterprise Software Engin...
# 4   AI Engineer (Computer Vision, Speech, NLP & Ge...
# 5   AI Engineer (Custom AI Solutions & GPT Tools) ...
# 6                   3D Printer Maintenance Technician
# 7                                  Senior AI Engineer
# 8                                 Senior Data Analyst
# 9                                  Senior AI Engineer
# 10  Fresh Electrical PLC & Planning Maintenace Eng...
# 11                       Software Development Manager
# 12              Research Scientist (AI) - Interactome
# 13    Senior Cost Accountant (Manufacturing Industry)
# 14                             AI Engineering Manager
# 15  Maintenance and Operations Supervisor (Technoc...
# 16                         Senior Python AI Developer
# 17                              Senior GIS Technician
# 18                 Production Internship - Alexandria
# 19                              Annotation Specialist
# 20                                 Production Chemist
# 21                   Mechanical Maintenance Engineers
# 22                            Data Engineer Team Lead
# 23                           Data Governance Engineer
# 24  Model maker / Assembly for 3D printing / Painting
# 25                       Pavement Assessment Engineer
# 26                                Production Engineer
# 27        Value-Based Healthcare Analytics Specialist
# 28                        Senior System Administrator
# 29                                  Chatbot Developer
# 30                       Associate Vendor Acquisition
# 31                        Next-JS Mid level Developer
# 32      AI & Computer Science Intern (Fresh Graduate)
# 33   Mechanical Maintenance Engineer (injection Mold)
# 34                                  Sr Java Developer
# 35  Junior Technical Support Engineer – Fresh Grad...
# 36                                   Sr Data Engineer
# 37                           Telesales Representative
# 38                                            Trainee
# 39                              Barista (Only Saudis)
# 40                        Strategic Account Executive
# 41                             Financial Data Analyst
# 42  Enterprise Account Executive - Telecoms - DACH...
# 43  Postdoctoral Research Fellow in Sustainable Co...
# 44                        RC RAK, Al Hamra Life Guard
#
#                                                  Link  \
# 0   https://wuzzuf.net/jobs/p/8oulgynroyag-data-sc...
# 1   https://wuzzuf.net/jobs/p/qgconbaaa2gf-ai-engi...
# 2   https://wuzzuf.net/jobs/p/bu1ksr9tke5x-data-sc...
# 3   https://wuzzuf.net/internship/2tshmlfj3ha9-gra...
# 4   https://wuzzuf.net/jobs/p/gofovnetfvvf-ai-engi...
# 5   https://wuzzuf.net/jobs/p/cfylkx2k6qh2-ai-engi...
# 6   https://wuzzuf.net/jobs/p/mgyqxkoukqrd-3d-prin...
# 7   https://wuzzuf.net/jobs/p/jQuD5uCDAOds-Senior-...
# 8   https://wuzzuf.net/jobs/p/kbzexl37bjxb-senior-...
# 9   https://wuzzuf.net/jobs/p/id9koixxt5zx-senior-...
# 10  https://wuzzuf.net/jobs/p/1xqbr0j7hc7z-fresh-e...
# 11  https://wuzzuf.net/jobs/p/6usftpppfu2x-softwar...
# 12  https://wuzzuf.net/jobs/p/g/wovnlx6nn74u-resea...
# 13  https://wuzzuf.net/jobs/p/btahdzswqdgs-senior-...
# 14  https://wuzzuf.net/jobs/p/x9ma4minmoqm-ai-engi...
# 15  https://wuzzuf.net/jobs/p/5tnwsyf0eirt-mainten...
# 16  https://wuzzuf.net/jobs/p/vab6snsugoi6-senior-...
# 17  https://wuzzuf.net/jobs/p/qedtihghtiwj-senior-...
# 18  https://wuzzuf.net/internship/ujaqy4pvuemd-pro...
# 19  https://wuzzuf.net/jobs/p/fitknhvaltf1-annotat...
# 20  https://wuzzuf.net/jobs/p/qt2plocgd0u0-product...
# 21  https://wuzzuf.net/jobs/p/1zkeyd9x7kq6-mechani...
# 22  https://wuzzuf.net/jobs/p/nudjhsulxmyk-data-en...
# 23  https://wuzzuf.net/jobs/p/olaufiqcjo1p-data-go...
# 24  https://wuzzuf.net/jobs/p/0xr4ytjvmsoh-model-m...
# 25  https://wuzzuf.net/jobs/p/70yqamm6eew8-pavemen...
# 26  https://wuzzuf.net/jobs/p/s16p7yktnroc-product...
# 27  https://wuzzuf.net/jobs/p/xfkkp9lu2duk-value-b...
# 28  https://wuzzuf.net/jobs/p/euz8tc4fcgya-senior-...
# 29  https://wuzzuf.net/jobs/p/lbj9cg78xnml-chatbot...
# 30  https://wuzzuf.net/internship/62usw4rqmm5p-ass...
# 31  https://wuzzuf.net/jobs/p/ctwiqqwu50qr-next-js...
# 32  https://wuzzuf.net/internship/jkoigewkbh8y-ai-...
# 33  https://wuzzuf.net/jobs/p/3ttzss59ja5h-mechani...
# 34  https://wuzzuf.net/jobs/p/ngobqzwqkaca-sr-java...
# 35  https://wuzzuf.net/jobs/p/O9dPht8vYERO-Junior-...
# 36  https://wuzzuf.net/jobs/p/ftd0zh3jscqe-sr-data...
# 37  https://wuzzuf.net/jobs/p/Zm8G6Qfw4zow-Telesal...
# 38  https://wuzzuf.net/jobs/p/g/zujy7cmgpqsi-train...
# 39  https://wuzzuf.net/jobs/p/g/mby3xkcwuril-baris...
# 40  https://wuzzuf.net/jobs/p/g/nwkfnybzc0kv-strat...
# 41  https://wuzzuf.net/jobs/p/g/jrvthu7qjoom-finan...
# 42  https://wuzzuf.net/jobs/p/g/ghfwy60ynpfp-enter...
# 43  https://wuzzuf.net/jobs/p/g/98wuvkecd2ca-postd...
# 44  https://wuzzuf.net/jobs/p/g/4ioljflktmnt-rc-ra...
#
#                                      Occupation  \
# 0                              Full TimeOn-site
# 1   Full TimePart TimeFreelance / ProjectHybrid
# 2                               Full TimeHybrid
# 3                              InternshipHybrid
# 4                               Full TimeRemote
# 5                              Full TimeOn-site
# 6                              Full TimeOn-site
# 7                               Full TimeHybrid
# 8                              Full TimeOn-site
# 9                               Full TimeHybrid
# 10                             Full TimeOn-site
# 11                              Full TimeHybrid
# 12                                    Full Time
# 13                             Full TimeOn-site
# 14                              Full TimeHybrid
# 15                             Full TimeOn-site
# 16                             Full TimeOn-site
# 17                             Full TimeOn-site
# 18                            InternshipOn-site
# 19                              Full TimeRemote
# 20                             Full TimeOn-site
# 21                             Full TimeOn-site
# 22                             Full TimeOn-site
# 23                              Full TimeHybrid
# 24                             Full TimeOn-site
# 25                             Full TimeOn-site
# 26                             Full TimeOn-site
# 27                             Full TimeOn-site
# 28                             Full TimeOn-site
# 29                              Full TimeHybrid
# 30                            InternshipOn-site
# 31                              Full TimeRemote
# 32                            InternshipOn-site
# 33                             Full TimeOn-site
# 34                              Full TimeHybrid
# 35                             Full TimeOn-site
# 36                              Full TimeHybrid
# 37                             Full TimeOn-site
# 38                                    Full Time
# 39                                    Full Time
# 40                                    Full Time
# 41                                    Full Time
# 42                                    Full Time
# 43                                    Full Time
# 44                                    Full Time
#
#                                         Company  \
# 0                                   Egabi FSI -
# 1                             ProVision Group -
# 2                                       Lumin -
# 3       eT3 - Tomorrow Information Technology -
# 4                                  Madar Soft -
# 5                       Stellar Charter Nexus -
# 6                             Gazelle 3D Tech -
# 7                                       Lumin -
# 8                        Xceed Contact Center -
# 9                            Link Development -
# 10              Modern Hygienic international -
# 11                               Confidential -
# 12                                  GenBio AI -
# 13  Selah ElTelmeez For Publishing & printing -
# 14                           Link Development -
# 15                            Eagle Chemicals -
# 16                                     Vigtas -
# 17                             Citylogix ME   -
# 18              Prometeon tyres group – Egypt -
# 19                                   Abwab.ai -
# 20                            Intertrade Co.  -
# 21                                 Lotus Tex  -
# 22                              COB Solution  -
# 23                  MOBILY INFOTECH LTD INDIA -
# 24                            Gazelle 3D Tech -
# 25                             Citylogix ME   -
# 26                 Zahranco Engineering Trade -
# 27               MEAHCO - Saudi German Health -
# 28                      Malvern College Egypt -
# 29                  MOBILY INFOTECH LTD INDIA -
# 30                                  Souqpress -
# 31                                  Techflipp -
# 32                  GetSircles Digital Agency -
# 33                               Confidential -
# 34                               SANTECHTURE  -
# 35                               Confidential -
# 36                               SANTECHTURE  -
# 37                               Confidential -
# 38                                    Space42 -
# 39                           Kempinski Hotels -
# 40                                  Canonical -
# 41                    Etihad Airport Services -
# 42                                  Canonical -
# 43                                  PhDFinder -
# 44                     Marriott International -
#
#                                                 Specs  \
# 0   Full TimeOn-siteEntry Level · 1 - 4 Yrs of Exp...
# 1   Full TimePart TimeFreelance / ProjectHybridExp...
# 2   Full TimeHybridExperienced · 3+ Yrs of Exp · I...
# 3   InternshipHybridEntry Level · IT/Software Deve...
# 4   Full TimeRemoteExperienced · 3 - 5 Yrs of Exp ...
# 5   Full TimeOn-siteExperienced · 2+ Yrs of Exp · ...
# 6   Full TimeOn-siteExperienced · 2+ Yrs of Exp · ...
# 7   Full TimeHybridExperienced · 3 - 5 Yrs of Exp ...
# 8   Full TimeOn-siteExperienced · 3+ Yrs of Exp · ...
# 9   Full TimeHybridExperienced · 2 - 5 Yrs of Exp ...
# 10  Full TimeOn-siteEntry Level · 0 - 1 Yrs of Exp...
# 11  Full TimeHybridManager · 10+ Yrs of Exp · Busi...
# 12  Full TimeNot specified · IT/Software Developme...
# 13  Full TimeOn-siteExperienced · 4 - 6 Yrs of Exp...
# 14  Full TimeHybridManager · 5+ Yrs of Exp · IT/So...
# 15  Full TimeOn-siteManager · 5 - 7 Yrs of Exp · I...
# 16  Full TimeOn-siteExperienced · 3 - 8 Yrs of Exp...
# 17  Full TimeOn-siteExperienced · 5 - 10 Yrs of Ex...
# 18  InternshipOn-siteEntry Level · 0 - 1 Yrs of Ex...
# 19  Full TimeRemoteEntry Level · 0 - 5 Yrs of Exp ...
# 20  Full TimeOn-siteExperienced · 2 - 4 Yrs of Exp...
# 21  Full TimeOn-siteEntry Level · Manufacturing/Pr...
# 22  Full TimeOn-siteManager · 4 - 6 Yrs of Exp · I...
# 23  Full TimeHybridExperienced · 6 - 10 Yrs of Exp...
# 24  Full TimeOn-siteEntry Level · 0 - 5 Yrs of Exp...
# 25  Full TimeOn-siteEntry Level · 0 - 4 Yrs of Exp...
# 26  Full TimeOn-siteEntry Level · 1 - 3 Yrs of Exp...
# 27  Full TimeOn-siteExperienced · 3 - 5 Yrs of Exp...
# 28  Full TimeOn-siteManager · 5 - 10 Yrs of Exp · ...
# 29  Full TimeHybridExperienced · 5 - 7 Yrs of Exp ...
# 30  InternshipOn-siteEntry Level · Sales/Retail · ...
# 31  Full TimeRemoteExperienced · 2 - 4 Yrs of Exp ...
# 32  InternshipOn-siteEntry Level · Other · compute...
# 33  Full TimeOn-siteEntry Level · 1 - 3 Yrs of Exp...
# 34  Full TimeHybridExperienced · 5+ Yrs of Exp · I...
# 35  Full TimeOn-siteEntry Level · Banking · Instal...
# 36  Full TimeHybridExperienced · 5+ Yrs of Exp · I...
# 37  Full TimeOn-siteExperienced · 1 - 3 Yrs of Exp...
# 38  Full TimeStudent · Accounting/Finance · Admini...
# 39  Full TimeEntry Level · Hospitality/Hotels/Food...
# 40  Full TimeExperienced · Customer Service/Suppor...
# 41  Full TimeExperienced · Accounting/Finance · IT...
# 42  Full TimeExperienced · Customer Service/Suppor...
# 43  Full TimeEntry Level · Engineering - Construct...
# 44  Full TimeEntry Level · Sports and Leisure · em...
#
#                                  Location
# 0                 Sheraton, Cairo, Egypt
# 1                    Maadi, Cairo, Egypt
# 2              Sheikh Zayed, Giza, Egypt
# 3                New Cairo, Cairo, Egypt
# 4             Fleming, Alexandria, Egypt
# 5                New Cairo, Cairo, Egypt
# 6            6th of October, Giza, Egypt
# 7              Sheikh Zayed, Giza, Egypt
# 8                           Cairo, Egypt
# 9                           Cairo, Egypt
# 10               Ain Sokhna, Suez, Egypt
# 11           6th of October, Giza, Egypt
# 12           Dubai, United Arab Emirates
# 13              Obour City, Cairo, Egypt
# 14                          Cairo, Egypt
# 15           6th of October, Giza, Egypt
# 16                          Cairo, Egypt
# 17               New Cairo, Cairo, Egypt
# 18             Ameria, Alexandria, Egypt
# 19                          Cairo, Egypt
# 20  10th of Ramadan City, Sharqia, Egypt
# 21  10th of Ramadan City, Sharqia, Egypt
# 22                   Maadi, Cairo, Egypt
# 23                          Cairo, Egypt
# 24           6th of October, Giza, Egypt
# 25               New Cairo, Cairo, Egypt
# 26           6th of October, Giza, Egypt
# 27                Katameya, Cairo, Egypt
# 28                Katameya, Cairo, Egypt
# 29               New Cairo, Cairo, Egypt
# 30           6th of October, Giza, Egypt
# 31                          Cairo, Egypt
# 32               New Cairo, Cairo, Egypt
# 33           6th of October, Giza, Egypt
# 34                Sheraton, Cairo, Egypt
# 35               New Cairo, Cairo, Egypt
# 36                Sheraton, Cairo, Egypt
# 37                  Riyadh, Saudi Arabia
# 38           Dubai, United Arab Emirates
# 39                  Riyadh, Saudi Arabia
# 40                  Makkah, Saudi Arabia
# 41           Dubai, United Arab Emirates
# 42                  Riyadh, Saudi Arabia
# 43           Dubai, United Arab Emirates
# 44  Ras al-Khaimah, United Arab Emirates

# %%
DA_df
# Out:
#                                                  Title  \
# 0                                  Senior Data Analyst
# 1                                         Data Analyst
# 2                 Information Analyst – Data Scientist
# 3                                       Data Scientist
# 4                                         Data Analyst
# ..                                                 ...
# 789                              COOP Training Program
# 790  Salesforce Engineering Manager, Commercial Sys...
# 791    Unmanned Aerial Vehicle System Chief Specialist
# 792                    Senior/Staff/Principal Engineer
# 793                         Revenue Management Officer
#
#                                                   Link        Occupation  \
# 0    https://wuzzuf.net/jobs/p/kbzexl37bjxb-senior-...  Full TimeOn-site
# 1    https://wuzzuf.net/jobs/p/aobcvsbixh2f-data-an...   Full TimeHybrid
# 2    https://wuzzuf.net/jobs/p/ric2lbqwad48-informa...   Full TimeRemote
# 3    https://wuzzuf.net/jobs/p/bu1ksr9tke5x-data-sc...   Full TimeHybrid
# 4    https://wuzzuf.net/jobs/p/zwllib1i7z5q-data-an...  Full TimeOn-site
# ..                                                 ...               ...
# 789  https://wuzzuf.net/jobs/p/g/kxnibpxbzph1-coop-...         Full Time
# 790  https://wuzzuf.net/jobs/p/g/ftuxaxpg2oio-sales...         Full Time
# 791  https://wuzzuf.net/jobs/p/g/d6npzmeejxwy-unman...         Full Time
# 792  https://wuzzuf.net/jobs/p/g/qwoy9gywfgv6-senio...         Full Time
# 793  https://wuzzuf.net/jobs/p/g/wx1tqx3y9vux-reven...         Full Time
#
#                               Company  \
# 0              Xceed Contact Center -
# 1                     Al Soug-Cashi -
# 2                      Confidential -
# 3                             Lumin -
# 4       Misr International Hospital -
# ..                                ...
# 789                    Tech Economy -
# 790                       Canonical -
# 791  Dubai Civil Aviation Authority -
# 792                       Canonical -
# 793                          Etihad -
#
#                                                  Specs  \
# 0    Full TimeOn-siteExperienced · 3+ Yrs of Exp · ...
# 1    Full TimeHybridExperienced · 1 - 5 Yrs of Exp ...
# 2    Full TimeRemoteExperienced · 5 - 8 Yrs of Exp ...
# 3    Full TimeHybridExperienced · 3+ Yrs of Exp · I...
# 4    Full TimeOn-siteExperienced · 2+ Yrs of Exp · ...
# ..                                                 ...
# 789  Full TimeStudent · Administration · Customer S...
# 790  Full TimeExperienced · IT/Software Development...
# 791  Full TimeExperienced · Creative/Design/Art · E...
# 792  Full TimeExperienced · IT/Software Development...
# 793  Full TimeEntry Level · Administration · Operat...
#
#                          Location
# 0                   Cairo, Egypt
# 1             Dokki, Giza, Egypt
# 2            Maadi, Cairo, Egypt
# 3      Sheikh Zayed, Giza, Egypt
# 4             Dokki, Giza, Egypt
# ..                            ...
# 789         Riyadh, Saudi Arabia
# 790         Makkah, Saudi Arabia
# 791  Dubai, United Arab Emirates
# 792         Riyadh, Saudi Arabia
# 793  Dubai, United Arab Emirates
#
# [794 rows x 6 columns]

# %%
DS_df
# Out:
#                                            Title  \
# 0           Product Manager – Data & AI Products
# 1                                 Data Scientist
# 2                                 Data Scientist
# 3           Information Analyst – Data Scientist
# 4                                   Data Analyst
# ..                                           ...
# 460                         Laboratory Assistant
# 461                                 HSE Engineer
# 462                              Content Creator
# 463                              Software Tester
# 464  EMEA Sales Director, ISV Embedded Solutions
#
#                                                   Link        Occupation  \
# 0    https://wuzzuf.net/jobs/p/7qu8aw9vozor-product...   Full TimeRemote
# 1    https://wuzzuf.net/jobs/p/8oulgynroyag-data-sc...  Full TimeOn-site
# 2    https://wuzzuf.net/jobs/p/bu1ksr9tke5x-data-sc...   Full TimeHybrid
# 3    https://wuzzuf.net/jobs/p/ric2lbqwad48-informa...   Full TimeRemote
# 4    https://wuzzuf.net/jobs/p/q3q0pe5ivmo0-data-an...  Full TimeOn-site
# ..                                                 ...               ...
# 460  https://wuzzuf.net/jobs/p/wgyqkqtvtk97-laborat...  Full TimeOn-site
# 461  https://wuzzuf.net/jobs/p/jPvww4jxKdz8-HSE-Eng...  Full TimeOn-site
# 462  https://wuzzuf.net/jobs/p/GXjFk6TbF6yg-Content...  Full TimeOn-site
# 463  https://wuzzuf.net/jobs/p/O6fE5lk5SNgN-Softwar...  Full TimeOn-site
# 464  https://wuzzuf.net/jobs/p/g/l6kb6jtxjjg6-emea-...         Full Time
#
#                                                Company  \
# 0                                         HiRemoters -
# 1                                          Egabi FSI -
# 2                                              Lumin -
# 3                                       Confidential -
# 4                                          Eltawheed -
# ..                                                 ...
# 460                               Torrecid Egypt SAE -
# 461                                        NILEWOOD  -
# 462                                   HRfoush Vision -
# 463  Aloha Dot for software development and financi...
# 464                                        Canonical -
#
#                                                  Specs  \
# 0    Full TimeRemoteExperienced · 2 - 5 Yrs of Exp ...
# 1    Full TimeOn-siteEntry Level · 1 - 4 Yrs of Exp...
# 2    Full TimeHybridExperienced · 3+ Yrs of Exp · I...
# 3    Full TimeRemoteExperienced · 5 - 8 Yrs of Exp ...
# 4    Full TimeOn-siteEntry Level · 1 - 4 Yrs of Exp...
# ..                                                 ...
# 460  Full TimeOn-siteEntry Level · 0 - 3 Yrs of Exp...
# 461  Full TimeOn-siteExperienced · 4 - 6 Yrs of Exp...
# 462  Full TimeOn-siteExperienced · 2 - 5 Yrs of Exp...
# 463  Full TimeOn-siteExperienced · 3 - 5 Yrs of Exp...
# 464  Full TimeManager · IT/Software Development · M...
#
#                                   Location
# 0                            Cairo, Egypt
# 1                  Sheraton, Cairo, Egypt
# 2               Sheikh Zayed, Giza, Egypt
# 3                     Maadi, Cairo, Egypt
# 4    10th of Ramadan City, Sharqia, Egypt
# ..                                     ...
# 460             Sheikh Zayed, Giza, Egypt
# 461          Alsadat City, Monufya, Egypt
# 462                          Cairo, Egypt
# 463                          Cairo, Egypt
# 464                  Makkah, Saudi Arabia
#
# [465 rows x 6 columns]

# %%
BI_df
# Out:
#                                                  Title  \
# 0                 Information Analyst – Data Scientist
# 1    Computer Science & Computer Engineering Fresh ...
# 2                                  Senior Data Analyst
# 3                             Junior Software Engineer
# 4                                           HR Manager
# ..                                                 ...
# 101                         Maintenance sales Engineer
# 102                                     Sales Engineer
# 103                     Value, Access and Pricing Lead
# 104                 Project Technical Delivery Manager
# 105  Projects Sales Engineer - Great Opportunity fo...
#
#                                                   Link        Occupation  \
# 0    https://wuzzuf.net/jobs/p/ric2lbqwad48-informa...   Full TimeRemote
# 1    https://wuzzuf.net/jobs/p/n5lfcli8ljdh-compute...  Full TimeOn-site
# 2    https://wuzzuf.net/jobs/p/kbzexl37bjxb-senior-...  Full TimeOn-site
# 3    https://wuzzuf.net/jobs/p/l9as0mvzljuq-junior-...  Full TimeOn-site
# 4    https://wuzzuf.net/jobs/p/szzfiacmad6k-hr-mana...  Full TimeOn-site
# ..                                                 ...               ...
# 101  https://wuzzuf.net/jobs/p/msxvgajwe5mg-mainten...  Full TimeOn-site
# 102  https://wuzzuf.net/jobs/p/Qy6kXIkbcfyT-Sales-E...  Full TimeOn-site
# 103  https://wuzzuf.net/jobs/p/g/gmwpq0uhmpch-value...         Full Time
# 104  https://wuzzuf.net/jobs/p/g/hmpain7zilgv-proje...         Full Time
# 105  https://wuzzuf.net/jobs/p/g/ijpogua8d3fe-proje...         Full Time
#
#                     Company  \
# 0            Confidential -
# 1            Confidential -
# 2    Xceed Contact Center -
# 3                MegaSoft -
# 4                      ma -
# ..                      ...
# 101               NAFFCO  -
# 102           VEC Trading -
# 103                Sanofi -
# 104                NVIDIA -
# 105               Siemens -
#
#                                                  Specs  \
# 0    Full TimeRemoteExperienced · 5 - 8 Yrs of Exp ...
# 1    Full TimeOn-siteEntry Level · 0 - 2 Yrs of Exp...
# 2    Full TimeOn-siteExperienced · 3+ Yrs of Exp · ...
# 3    Full TimeOn-siteEntry Level · 0 - 2 Yrs of Exp...
# 4    Full TimeOn-siteManager · 3+ Yrs of Exp · Huma...
# ..                                                 ...
# 101  Full TimeOn-siteExperienced · 3 - 8 Yrs of Exp...
# 102  Full TimeOn-siteEntry Level · 1 - 5 Yrs of Exp...
# 103  Full TimeExperienced · Customer Service/Suppor...
# 104  Full TimeExperienced · IT/Software Development...
# 105  Full TimeEntry Level · Engineering - Construct...
#
#                          Location
# 0            Maadi, Cairo, Egypt
# 1       Heliopolis, Cairo, Egypt
# 2                   Cairo, Egypt
# 3       Heliopolis, Cairo, Egypt
# 4                   Cairo, Egypt
# ..                            ...
# 101                  Giza, Egypt
# 102                 Cairo, Egypt
# 103         Riyadh, Saudi Arabia
# 104  Dubai, United Arab Emirates
# 105         Riyadh, Saudi Arabia
#
# [106 rows x 6 columns]

# %%
all_df = pd.concat([ML_df,DA_df,DS_df,BI_df],ignore_index=True)
all_df
# Out:
#                                                   Title  \
# 0                                        Data Scientist
# 1                                           AI Engineer
# 2                                        Data Scientist
# 3     Graduate Internship: Enterprise Software Engin...
# 4     AI Engineer (Computer Vision, Speech, NLP & Ge...
# ...                                                 ...
# 1405                         Maintenance sales Engineer
# 1406                                     Sales Engineer
# 1407                     Value, Access and Pricing Lead
# 1408                 Project Technical Delivery Manager
# 1409  Projects Sales Engineer - Great Opportunity fo...
#
#                                                    Link  \
# 0     https://wuzzuf.net/jobs/p/8oulgynroyag-data-sc...
# 1     https://wuzzuf.net/jobs/p/qgconbaaa2gf-ai-engi...
# 2     https://wuzzuf.net/jobs/p/bu1ksr9tke5x-data-sc...
# 3     https://wuzzuf.net/internship/2tshmlfj3ha9-gra...
# 4     https://wuzzuf.net/jobs/p/gofovnetfvvf-ai-engi...
# ...                                                 ...
# 1405  https://wuzzuf.net/jobs/p/msxvgajwe5mg-mainten...
# 1406  https://wuzzuf.net/jobs/p/Qy6kXIkbcfyT-Sales-E...
# 1407  https://wuzzuf.net/jobs/p/g/gmwpq0uhmpch-value...
# 1408  https://wuzzuf.net/jobs/p/g/hmpain7zilgv-proje...
# 1409  https://wuzzuf.net/jobs/p/g/ijpogua8d3fe-proje...
#
#                                        Occupation  \
# 0                                Full TimeOn-site
# 1     Full TimePart TimeFreelance / ProjectHybrid
# 2                                 Full TimeHybrid
# 3                                InternshipHybrid
# 4                                 Full TimeRemote
# ...                                           ...
# 1405                             Full TimeOn-site
# 1406                             Full TimeOn-site
# 1407                                    Full Time
# 1408                                    Full Time
# 1409                                    Full Time
#
#                                       Company  \
# 0                                 Egabi FSI -
# 1                           ProVision Group -
# 2                                     Lumin -
# 3     eT3 - Tomorrow Information Technology -
# 4                                Madar Soft -
# ...                                       ...
# 1405                                NAFFCO  -
# 1406                            VEC Trading -
# 1407                                 Sanofi -
# 1408                                 NVIDIA -
# 1409                                Siemens -
#
#                                                   Specs  \
# 0     Full TimeOn-siteEntry Level · 1 - 4 Yrs of Exp...
# 1     Full TimePart TimeFreelance / ProjectHybridExp...
# 2     Full TimeHybridExperienced · 3+ Yrs of Exp · I...
# 3     InternshipHybridEntry Level · IT/Software Deve...
# 4     Full TimeRemoteExperienced · 3 - 5 Yrs of Exp ...
# ...                                                 ...
# 1405  Full TimeOn-siteExperienced · 3 - 8 Yrs of Exp...
# 1406  Full TimeOn-siteEntry Level · 1 - 5 Yrs of Exp...
# 1407  Full TimeExperienced · Customer Service/Suppor...
# 1408  Full TimeExperienced · IT/Software Development...
# 1409  Full TimeEntry Level · Engineering - Construct...
#
#                           Location
# 0          Sheraton, Cairo, Egypt
# 1             Maadi, Cairo, Egypt
# 2       Sheikh Zayed, Giza, Egypt
# 3         New Cairo, Cairo, Egypt
# 4      Fleming, Alexandria, Egypt
# ...                            ...
# 1405                  Giza, Egypt
# 1406                 Cairo, Egypt
# 1407         Riyadh, Saudi Arabia
# 1408  Dubai, United Arab Emirates
# 1409         Riyadh, Saudi Arabia
#
# [1410 rows x 6 columns]

# %%
all_df.to_csv("ml_jobs.csv",index=False)
